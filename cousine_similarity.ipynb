# %% [markdown]
# ### Prompt to generate list of words
# Please produce list of 7 word as python list of tuples in English and Russian language
# like [('snow', 'cнег'), ('winter sport', 'зимние виды спорта'), ...]
# Some of that words should be semantically close, some of them - not, so that we can use these words for exploration of cousin similarity using vector embeddings

# %%
from sentence_transformers import SentenceTransformer, util

def calculate_similarity(model, sent1, sent2):
    embeddings = model.encode([sent1, sent2])
    return util.pytorch_cos_sim(embeddings[0], embeddings[1]).item()

models = [
    SentenceTransformer('all-mpnet-base-v2'),
    SentenceTransformer('ai-forever/sbert_large_nlu_ru'),
    SentenceTransformer('distiluse-base-multilingual-cased-v1'),
]
# 'DeepPavlov/rubert-base-cased-sentence' getting 'No sentence-transformers model found with name DeepPavlov/rubert-base-cased-sentence. Creating a new one with MEAN pooling.'
# Out:
# /Users/dklmn/.local/share/virtualenvs/telegram_rag_search-oI0nq4RM/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# You try to use a model that was created with version 3.0.0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# /Users/dklmn/.local/share/virtualenvs/telegram_rag_search-oI0nq4RM/lib/python3.12/site-packages/sentence_transformers/models/Dense.py:77: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(os.path.join(input_path, "pytorch_model.bin"), map_location=torch.device("cpu"))

# %%
import itertools
from tqdm import tqdm
import pandas as pd

words_en_ru = [
    ('snow', 'снег'),
    ('winter sports', 'зимние виды спорта'),
    ('Ski', 'лыжи'),
    ('Sad', 'грустный'),
    ('sorrowful', 'печальный'),
    ('wish yor were here', 'хотел бы чтобы ты был здесь'),
    ('Pink floyd', 'Pink floyd'),
    ('pink panter', 'розовая пантера'),
    ('cafe', 'кафе'),
    ('tasty food', 'вкусная еда'),
    ('music', 'музыка'),
    ('guitar', 'гитара')
]

# Generate all pairs of sentences, excluding identical pairs
pairs = list(itertools.combinations(words_en_ru, 2))
# Calculate similarities and store results
results = []
columns=['Word 1 EN', 'Word 2 EN', 'Sim(EN by Base)', 'Sim(EN by RU)' , 'Sim(EN by Mult)', 
         'Word 1 RU', 'Word 2 RU', 'Sim(RU by Base)', 'Sim(RU by RU)' , 'Sim(RU by Mult)']
for sent1, sent2 in tqdm(pairs): 
    row_array = []   
    for i_lang, lang in enumerate(['EN', 'RU']):
        row_array.extend([sent1[i_lang], sent2[i_lang]])
        sims = []
        for model in models:
            ss = (sent1[i_lang], sent2[i_lang])
            sims.append(calculate_similarity(model, *ss))
        row_array.extend(sims)
    results.append(row_array)
df = pd.DataFrame(results, columns=columns)
df.shape
# Out:
# 100%|██████████| 66/66 [00:13<00:00,  5.02it/s]
# (66, 10)

# %%
pd.set_option('display.max_rows', 100)  
word_columns=['Word 1 EN', 'Word 2 EN', 'Word 1 RU', 'Word 2 RU',]
sim_columns = columns=['Sim(EN by Base)', 'Sim(EN by RU)' , 'Sim(EN by Mult)', 'Sim(RU by Base)', 'Sim(RU by RU)' , 'Sim(RU by Mult)']

for col in sim_columns: 
    df.sort_values(by=col, inplace=True,ascending=False)
    df['Rank'] = df[col].rank(method='min', ascending=False)
    cc = word_columns + [col, 'Rank']
    subset_df = df[cc]
    print(f'sorted by {col}')
    display(subset_df)
# Out:
# sorted by Sim(EN by Base)
#              Word 1 EN           Word 2 EN                    Word 1 RU  \
# 11       winter sports                 Ski           зимние виды спорта
# 0                 snow       winter sports                         снег
# 30                 Sad           sorrowful                     грустный
# 54          Pink floyd               music                   Pink floyd
# 1                 snow                 Ski                         снег
# 55          Pink floyd              guitar                   Pink floyd
# 65               music              guitar                       музыка
# 63          tasty food               music                  вкусная еда
# 51          Pink floyd         pink panter                   Pink floyd
# 60                cafe          tasty food                         кафе
# 31                 Sad  wish yor were here                     грустный
# 9                 snow               music                         снег
# 42           sorrowful          tasty food                    печальный
# 38           sorrowful  wish yor were here                    печальный
# 36                 Sad               music                     грустный
# 53          Pink floyd          tasty food                   Pink floyd
# 8                 snow          tasty food                         снег
# 3                 snow           sorrowful                         снег
# 52          Pink floyd                cafe                   Pink floyd
# 39           sorrowful          Pink floyd                    печальный
# 16       winter sports         pink panter           зимние виды спорта
# 43           sorrowful               music                    печальный
# 26                 Ski                cafe                         лыжи
# 41           sorrowful                cafe                    печальный
# 56         pink panter                cafe              розовая пантера
# 61                cafe               music                         кафе
# 6                 snow         pink panter                         снег
# 19       winter sports               music           зимние виды спорта
# 35                 Sad          tasty food                     грустный
# 48  wish yor were here          tasty food  хотел бы чтобы ты был здесь
# 62                cafe              guitar                         кафе
# 29                 Ski              guitar                         лыжи
# 21                 Ski                 Sad                         лыжи
# 34                 Sad                cafe                     грустный
# 5                 snow          Pink floyd                         снег
# 17       winter sports                cafe           зимние виды спорта
# 59         pink panter              guitar              розовая пантера
# 2                 snow                 Sad                         снег
# 40           sorrowful         pink panter                    печальный
# 32                 Sad          Pink floyd                     грустный
# 10                snow              guitar                         снег
# 28                 Ski               music                         лыжи
# 49  wish yor were here               music  хотел бы чтобы ты был здесь
# 18       winter sports          tasty food           зимние виды спорта
# 7                 snow                cafe                         снег
# 20       winter sports              guitar           зимние виды спорта
# 27                 Ski          tasty food                         лыжи
# 13       winter sports           sorrowful           зимние виды спорта
# 64          tasty food              guitar                  вкусная еда
# 57         pink panter          tasty food              розовая пантера
# 12       winter sports                 Sad           зимние виды спорта
# 25                 Ski         pink panter                         лыжи
# 22                 Ski           sorrowful                         лыжи
# 45  wish yor were here          Pink floyd  хотел бы чтобы ты был здесь
# 44           sorrowful              guitar                    печальный
# 33                 Sad         pink panter                     грустный
# 37                 Sad              guitar                     грустный
# 58         pink panter               music              розовая пантера
# 23                 Ski  wish yor were here                         лыжи
# 4                 snow  wish yor were here                         снег
# 15       winter sports          Pink floyd           зимние виды спорта
# 14       winter sports  wish yor were here           зимние виды спорта
# 46  wish yor were here         pink panter  хотел бы чтобы ты был здесь
# 24                 Ski          Pink floyd                         лыжи
# 50  wish yor were here              guitar  хотел бы чтобы ты был здесь
# 47  wish yor were here                cafe  хотел бы чтобы ты был здесь
#
#                       Word 2 RU  Sim(EN by Base)  Rank
# 11                         лыжи         0.701170   1.0
# 0            зимние виды спорта         0.590515   2.0
# 30                    печальный         0.576371   3.0
# 54                       музыка         0.501653   4.0
# 1                          лыжи         0.472321   5.0
# 55                       гитара         0.410168   6.0
# 65                       гитара         0.399208   7.0
# 63                       музыка         0.383167   8.0
# 51              розовая пантера         0.360010   9.0
# 60                  вкусная еда         0.318768  10.0
# 31  хотел бы чтобы ты был здесь         0.312710  11.0
# 9                        музыка         0.309878  12.0
# 42                  вкусная еда         0.279951  13.0
# 38  хотел бы чтобы ты был здесь         0.253053  14.0
# 36                       музыка         0.243772  15.0
# 53                  вкусная еда         0.241261  16.0
# 8                   вкусная еда         0.231503  17.0
# 3                     печальный         0.230165  18.0
# 52                         кафе         0.229532  19.0
# 39                   Pink floyd         0.226525  20.0
# 16              розовая пантера         0.225683  21.0
# 43                       музыка         0.220145  22.0
# 26                         кафе         0.219984  23.0
# 41                         кафе         0.210186  24.0
# 56                         кафе         0.205350  25.0
# 61                       музыка         0.202866  26.0
# 6               розовая пантера         0.201910  27.0
# 19                       музыка         0.195569  28.0
# 35                  вкусная еда         0.189874  29.0
# 48                  вкусная еда         0.182723  30.0
# 62                       гитара         0.181070  31.0
# 29                       гитара         0.180464  32.0
# 21                     грустный         0.179419  33.0
# 34                         кафе         0.176816  34.0
# 5                    Pink floyd         0.174293  35.0
# 17                         кафе         0.172622  36.0
# 59                       гитара         0.172189  37.0
# 2                      грустный         0.169632  38.0
# 40              розовая пантера         0.167569  39.0
# 32                   Pink floyd         0.165357  40.0
# 10                       гитара         0.164363  41.0
# 28                       музыка         0.163125  42.0
# 49                       музыка         0.162385  43.0
# 18                  вкусная еда         0.160729  44.0
# 7                          кафе         0.160708  45.0
# 20                       гитара         0.153377  46.0
# 27                  вкусная еда         0.152561  47.0
# 13                    печальный         0.144511  48.0
# 64                       гитара         0.142602  49.0
# 57                  вкусная еда         0.142542  50.0
# 12                     грустный         0.131872  51.0
# 25              розовая пантера         0.130836  52.0
# 22                    печальный         0.127083  53.0
# 45                   Pink floyd         0.116523  54.0
# 44                       гитара         0.115688  55.0
# 33              розовая пантера         0.111136  56.0
# 37                       гитара         0.108652  57.0
# 58                       музыка         0.107671  58.0
# 23  хотел бы чтобы ты был здесь         0.105948  59.0
# 4   хотел бы чтобы ты был здесь         0.083650  60.0
# 15                   Pink floyd         0.082004  61.0
# 14  хотел бы чтобы ты был здесь         0.077113  62.0
# 46              розовая пантера         0.065224  63.0
# 24                   Pink floyd         0.055178  64.0
# 50                       гитара         0.053031  65.0
# 47                         кафе         0.035511  66.0
# sorted by Sim(EN by RU)
#              Word 1 EN           Word 2 EN                    Word 1 RU  \
# 51          Pink floyd         pink panter                   Pink floyd
# 65               music              guitar                       музыка
# 56         pink panter                cafe              розовая пантера
# 53          Pink floyd          tasty food                   Pink floyd
# 57         pink panter          tasty food              розовая пантера
# 26                 Ski                cafe                         лыжи
# 34                 Sad                cafe                     грустный
# 1                 snow                 Ski                         снег
# 55          Pink floyd              guitar                   Pink floyd
# 5                 snow          Pink floyd                         снег
# 9                 snow               music                         снег
# 10                snow              guitar                         снег
# 7                 snow                cafe                         снег
# 54          Pink floyd               music                   Pink floyd
# 52          Pink floyd                cafe                   Pink floyd
# 39           sorrowful          Pink floyd                    печальный
# 3                 snow           sorrowful                         снег
# 25                 Ski         pink panter                         лыжи
# 6                 snow         pink panter                         снег
# 8                 snow          tasty food                         снег
# 44           sorrowful              guitar                    печальный
# 42           sorrowful          tasty food                    печальный
# 24                 Ski          Pink floyd                         лыжи
# 40           sorrowful         pink panter                    печальный
# 43           sorrowful               music                    печальный
# 41           sorrowful                cafe                    печальный
# 15       winter sports          Pink floyd           зимние виды спорта
# 63          tasty food               music                  вкусная еда
# 29                 Ski              guitar                         лыжи
# 38           sorrowful  wish yor were here                    печальный
# 58         pink panter               music              розовая пантера
# 59         pink panter              guitar              розовая пантера
# 22                 Ski           sorrowful                         лыжи
# 28                 Ski               music                         лыжи
# 19       winter sports               music           зимние виды спорта
# 18       winter sports          tasty food           зимние виды спорта
# 61                cafe               music                         кафе
# 48  wish yor were here          tasty food  хотел бы чтобы ты был здесь
# 62                cafe              guitar                         кафе
# 45  wish yor were here          Pink floyd  хотел бы чтобы ты был здесь
# 21                 Ski                 Sad                         лыжи
# 4                 snow  wish yor were here                         снег
# 16       winter sports         pink panter           зимние виды спорта
# 60                cafe          tasty food                         кафе
# 64          tasty food              guitar                  вкусная еда
# 33                 Sad         pink panter                     грустный
# 13       winter sports           sorrowful           зимние виды спорта
# 27                 Ski          tasty food                         лыжи
# 46  wish yor were here         pink panter  хотел бы чтобы ты был здесь
# 23                 Ski  wish yor were here                         лыжи
# 50  wish yor were here              guitar  хотел бы чтобы ты был здесь
# 20       winter sports              guitar           зимние виды спорта
# 17       winter sports                cafe           зимние виды спорта
# 0                 snow       winter sports                         снег
# 47  wish yor were here                cafe  хотел бы чтобы ты был здесь
# 49  wish yor were here               music  хотел бы чтобы ты был здесь
# 11       winter sports                 Ski           зимние виды спорта
# 2                 snow                 Sad                         снег
# 14       winter sports  wish yor were here           зимние виды спорта
# 32                 Sad          Pink floyd                     грустный
# 35                 Sad          tasty food                     грустный
# 30                 Sad           sorrowful                     грустный
# 36                 Sad               music                     грустный
# 31                 Sad  wish yor were here                     грустный
# 37                 Sad              guitar                     грустный
# 12       winter sports                 Sad           зимние виды спорта
#
#                       Word 2 RU  Sim(EN by RU)  Rank
# 51              розовая пантера       0.924591   1.0
# 65                       гитара       0.853080   2.0
# 56                         кафе       0.826093   3.0
# 53                  вкусная еда       0.824252   4.0
# 57                  вкусная еда       0.819045   5.0
# 26                         кафе       0.803761   6.0
# 34                         кафе       0.801131   7.0
# 1                          лыжи       0.791520   8.0
# 55                       гитара       0.789780   9.0
# 5                    Pink floyd       0.786584  10.0
# 9                        музыка       0.774006  11.0
# 10                       гитара       0.771075  12.0
# 7                          кафе       0.769643  13.0
# 54                       музыка       0.769618  14.0
# 52                         кафе       0.764610  15.0
# 39                   Pink floyd       0.759218  16.0
# 3                     печальный       0.758643  17.0
# 25              розовая пантера       0.749938  18.0
# 6               розовая пантера       0.747172  19.0
# 8                   вкусная еда       0.747013  20.0
# 44                       гитара       0.739952  21.0
# 42                  вкусная еда       0.737813  22.0
# 24                   Pink floyd       0.737567  23.0
# 40              розовая пантера       0.730650  24.0
# 43                       музыка       0.729913  25.0
# 41                         кафе       0.724529  26.0
# 15                   Pink floyd       0.718557  27.0
# 63                       музыка       0.715676  28.0
# 29                       гитара       0.714256  29.0
# 38  хотел бы чтобы ты был здесь       0.713474  30.0
# 58                       музыка       0.710069  31.0
# 59                       гитара       0.705698  32.0
# 22                    печальный       0.704331  33.0
# 28                       музыка       0.701267  34.0
# 19                       музыка       0.700248  35.0
# 18                  вкусная еда       0.699035  36.0
# 61                       музыка       0.693501  37.0
# 48                  вкусная еда       0.692164  38.0
# 62                       гитара       0.690756  39.0
# 45                   Pink floyd       0.690544  40.0
# 21                     грустный       0.685679  41.0
# 4   хотел бы чтобы ты был здесь       0.683165  42.0
# 16              розовая пантера       0.683138  43.0
# 60                  вкусная еда       0.681532  44.0
# 64                       гитара       0.676414  45.0
# 33              розовая пантера       0.673688  46.0
# 13                    печальный       0.661220  47.0
# 27                  вкусная еда       0.660528  48.0
# 46              розовая пантера       0.659341  49.0
# 23  хотел бы чтобы ты был здесь       0.656568  50.0
# 50                       гитара       0.630793  51.0
# 20                       гитара       0.627176  52.0
# 17                         кафе       0.625901  53.0
# 0            зимние виды спорта       0.618713  54.0
# 47                         кафе       0.612707  55.0
# 49                       музыка       0.612491  56.0
# 11                         лыжи       0.576924  57.0
# 2                      грустный       0.567632  58.0
# 14  хотел бы чтобы ты был здесь       0.545168  59.0
# 32                   Pink floyd       0.534071  60.0
# 35                  вкусная еда       0.473634  61.0
# 30                    печальный       0.456301  62.0
# 36                       музыка       0.445714  63.0
# 31  хотел бы чтобы ты был здесь       0.437302  64.0
# 37                       гитара       0.417169  65.0
# 12                     грустный       0.377154  66.0
# sorted by Sim(EN by Mult)
#              Word 1 EN           Word 2 EN                    Word 1 RU  \
# 30                 Sad           sorrowful                     грустный
# 51          Pink floyd         pink panter                   Pink floyd
# 1                 snow                 Ski                         снег
# 65               music              guitar                       музыка
# 0                 snow       winter sports                         снег
# 11       winter sports                 Ski           зимние виды спорта
# 29                 Ski              guitar                         лыжи
# 10                snow              guitar                         снег
# 3                 snow           sorrowful                         снег
# 28                 Ski               music                         лыжи
# 63          tasty food               music                  вкусная еда
# 9                 snow               music                         снег
# 60                cafe          tasty food                         кафе
# 2                 snow                 Sad                         снег
# 26                 Ski                cafe                         лыжи
# 7                 snow                cafe                         снег
# 19       winter sports               music           зимние виды спорта
# 61                cafe               music                         кафе
# 62                cafe              guitar                         кафе
# 40           sorrowful         pink panter                    печальный
# 36                 Sad               music                     грустный
# 37                 Sad              guitar                     грустный
# 6                 snow         pink panter                         снег
# 44           sorrowful              guitar                    печальный
# 39           sorrowful          Pink floyd                    печальный
# 43           sorrowful               music                    печальный
# 33                 Sad         pink panter                     грустный
# 42           sorrowful          tasty food                    печальный
# 21                 Ski                 Sad                         лыжи
# 25                 Ski         pink panter                         лыжи
# 18       winter sports          tasty food           зимние виды спорта
# 59         pink panter              guitar              розовая пантера
# 56         pink panter                cafe              розовая пантера
# 22                 Ski           sorrowful                         лыжи
# 35                 Sad          tasty food                     грустный
# 32                 Sad          Pink floyd                     грустный
# 5                 snow          Pink floyd                         снег
# 57         pink panter          tasty food              розовая пантера
# 58         pink panter               music              розовая пантера
# 24                 Ski          Pink floyd                         лыжи
# 41           sorrowful                cafe                    печальный
# 27                 Ski          tasty food                         лыжи
# 34                 Sad                cafe                     грустный
# 8                 snow          tasty food                         снег
# 20       winter sports              guitar           зимние виды спорта
# 64          tasty food              guitar                  вкусная еда
# 53          Pink floyd          tasty food                   Pink floyd
# 55          Pink floyd              guitar                   Pink floyd
# 54          Pink floyd               music                   Pink floyd
# 17       winter sports                cafe           зимние виды спорта
# 31                 Sad  wish yor were here                     грустный
# 16       winter sports         pink panter           зимние виды спорта
# 12       winter sports                 Sad           зимние виды спорта
# 50  wish yor were here              guitar  хотел бы чтобы ты был здесь
# 4                 snow  wish yor were here                         снег
# 13       winter sports           sorrowful           зимние виды спорта
# 38           sorrowful  wish yor were here                    печальный
# 52          Pink floyd                cafe                   Pink floyd
# 23                 Ski  wish yor were here                         лыжи
# 47  wish yor were here                cafe  хотел бы чтобы ты был здесь
# 49  wish yor were here               music  хотел бы чтобы ты был здесь
# 46  wish yor were here         pink panter  хотел бы чтобы ты был здесь
# 15       winter sports          Pink floyd           зимние виды спорта
# 45  wish yor were here          Pink floyd  хотел бы чтобы ты был здесь
# 48  wish yor were here          tasty food  хотел бы чтобы ты был здесь
# 14       winter sports  wish yor were here           зимние виды спорта
#
#                       Word 2 RU  Sim(EN by Mult)  Rank
# 30                    печальный         0.912052   1.0
# 51              розовая пантера         0.819969   2.0
# 1                          лыжи         0.719410   3.0
# 65                       гитара         0.594409   4.0
# 0            зимние виды спорта         0.567100   5.0
# 11                         лыжи         0.565557   6.0
# 29                       гитара         0.396769   7.0
# 10                       гитара         0.377323   8.0
# 3                     печальный         0.376097   9.0
# 28                       музыка         0.363767  10.0
# 63                       музыка         0.362812  11.0
# 9                        музыка         0.362637  12.0
# 60                  вкусная еда         0.362284  13.0
# 2                      грустный         0.360554  14.0
# 26                         кафе         0.358285  15.0
# 7                          кафе         0.355055  16.0
# 19                       музыка         0.347201  17.0
# 61                       музыка         0.343790  18.0
# 62                       гитара         0.327925  19.0
# 40              розовая пантера         0.327753  20.0
# 36                       музыка         0.326869  21.0
# 37                       гитара         0.320208  22.0
# 6               розовая пантера         0.314971  23.0
# 44                       гитара         0.306916  24.0
# 39                   Pink floyd         0.304899  25.0
# 43                       музыка         0.302693  26.0
# 33              розовая пантера         0.294608  27.0
# 42                  вкусная еда         0.290428  28.0
# 21                     грустный         0.281506  29.0
# 25              розовая пантера         0.277696  30.0
# 18                  вкусная еда         0.269117  31.0
# 59                       гитара         0.267546  32.0
# 56                         кафе         0.266632  33.0
# 22                    печальный         0.265695  34.0
# 35                  вкусная еда         0.264832  35.0
# 32                   Pink floyd         0.263327  36.0
# 5                    Pink floyd         0.262581  37.0
# 57                  вкусная еда         0.262042  38.0
# 58                       музыка         0.261518  39.0
# 24                   Pink floyd         0.260174  40.0
# 41                         кафе         0.254807  41.0
# 27                  вкусная еда         0.253118  42.0
# 34                         кафе         0.247612  43.0
# 8                   вкусная еда         0.241680  44.0
# 20                       гитара         0.240513  45.0
# 64                       гитара         0.237435  46.0
# 53                  вкусная еда         0.229740  47.0
# 55                       гитара         0.226138  48.0
# 54                       музыка         0.217801  49.0
# 17                         кафе         0.215623  50.0
# 31  хотел бы чтобы ты был здесь         0.210884  51.0
# 16              розовая пантера         0.192556  52.0
# 12                     грустный         0.184446  53.0
# 50                       гитара         0.182439  54.0
# 4   хотел бы чтобы ты был здесь         0.174710  55.0
# 13                    печальный         0.172748  56.0
# 38  хотел бы чтобы ты был здесь         0.158090  57.0
# 52                         кафе         0.157943  58.0
# 23  хотел бы чтобы ты был здесь         0.147399  59.0
# 47                         кафе         0.135897  60.0
# 49                       музыка         0.129942  61.0
# 46              розовая пантера         0.129599  62.0
# 15                   Pink floyd         0.129366  63.0
# 45                   Pink floyd         0.116292  64.0
# 48                  вкусная еда         0.102889  65.0
# 14  хотел бы чтобы ты был здесь         0.100925  66.0
# sorted by Sim(RU by Base)
#              Word 1 EN           Word 2 EN                    Word 1 RU  \
# 37                 Sad              guitar                     грустный
# 28                 Ski               music                         лыжи
# 18       winter sports          tasty food           зимние виды спорта
# 65               music              guitar                       музыка
# 2                 snow                 Sad                         снег
# 1                 snow                 Ski                         снег
# 36                 Sad               music                     грустный
# 10                snow              guitar                         снег
# 63          tasty food               music                  вкусная еда
# 26                 Ski                cafe                         лыжи
# 9                 snow               music                         снег
# 35                 Sad          tasty food                     грустный
# 64          tasty food              guitar                  вкусная еда
# 61                cafe               music                         кафе
# 22                 Ski           sorrowful                         лыжи
# 29                 Ski              guitar                         лыжи
# 21                 Ski                 Sad                         лыжи
# 43           sorrowful               music                    печальный
# 30                 Sad           sorrowful                     грустный
# 40           sorrowful         pink panter                    печальный
# 27                 Ski          tasty food                         лыжи
# 14       winter sports  wish yor were here           зимние виды спорта
# 38           sorrowful  wish yor were here                    печальный
# 16       winter sports         pink panter           зимние виды спорта
# 33                 Sad         pink panter                     грустный
# 13       winter sports           sorrowful           зимние виды спорта
# 59         pink panter              guitar              розовая пантера
# 42           sorrowful          tasty food                    печальный
# 8                 snow          tasty food                         снег
# 7                 snow                cafe                         снег
# 62                cafe              guitar                         кафе
# 12       winter sports                 Sad           зимние виды спорта
# 57         pink panter          tasty food              розовая пантера
# 60                cafe          tasty food                         кафе
# 58         pink panter               music              розовая пантера
# 19       winter sports               music           зимние виды спорта
# 3                 snow           sorrowful                         снег
# 48  wish yor were here          tasty food  хотел бы чтобы ты был здесь
# 34                 Sad                cafe                     грустный
# 20       winter sports              guitar           зимние виды спорта
# 41           sorrowful                cafe                    печальный
# 44           sorrowful              guitar                    печальный
# 0                 snow       winter sports                         снег
# 23                 Ski  wish yor were here                         лыжи
# 6                 snow         pink panter                         снег
# 56         pink panter                cafe              розовая пантера
# 49  wish yor were here               music  хотел бы чтобы ты был здесь
# 25                 Ski         pink panter                         лыжи
# 11       winter sports                 Ski           зимние виды спорта
# 46  wish yor were here         pink panter  хотел бы чтобы ты был здесь
# 4                 snow  wish yor were here                         снег
# 31                 Sad  wish yor were here                     грустный
# 17       winter sports                cafe           зимние виды спорта
# 47  wish yor were here                cafe  хотел бы чтобы ты был здесь
# 50  wish yor were here              guitar  хотел бы чтобы ты был здесь
# 24                 Ski          Pink floyd                         лыжи
# 54          Pink floyd               music                   Pink floyd
# 52          Pink floyd                cafe                   Pink floyd
# 55          Pink floyd              guitar                   Pink floyd
# 32                 Sad          Pink floyd                     грустный
# 39           sorrowful          Pink floyd                    печальный
# 5                 snow          Pink floyd                         снег
# 53          Pink floyd          tasty food                   Pink floyd
# 15       winter sports          Pink floyd           зимние виды спорта
# 51          Pink floyd         pink panter                   Pink floyd
# 45  wish yor were here          Pink floyd  хотел бы чтобы ты был здесь
#
#                       Word 2 RU  Sim(RU by Base)  Rank
# 37                       гитара         0.928943   1.0
# 28                       музыка         0.794958   2.0
# 18                  вкусная еда         0.726518   3.0
# 65                       гитара         0.721338   4.0
# 2                      грустный         0.712263   5.0
# 1                          лыжи         0.711367   6.0
# 36                       музыка         0.705755   7.0
# 10                       гитара         0.699609   8.0
# 63                       музыка         0.693135   9.0
# 26                         кафе         0.691134  10.0
# 9                        музыка         0.690273  11.0
# 35                  вкусная еда         0.683703  12.0
# 64                       гитара         0.679909  13.0
# 61                       музыка         0.677717  14.0
# 22                    печальный         0.677369  15.0
# 29                       гитара         0.670298  16.0
# 21                     грустный         0.669857  17.0
# 43                       музыка         0.664569  18.0
# 30                    печальный         0.663810  19.0
# 40              розовая пантера         0.660310  20.0
# 27                  вкусная еда         0.658623  21.0
# 14  хотел бы чтобы ты был здесь         0.653956  22.0
# 38  хотел бы чтобы ты был здесь         0.642611  23.0
# 16              розовая пантера         0.639638  24.0
# 33              розовая пантера         0.639229  25.0
# 13                    печальный         0.637454  26.0
# 59                       гитара         0.633115  27.0
# 42                  вкусная еда         0.632623  28.0
# 8                   вкусная еда         0.630552  29.0
# 7                          кафе         0.629130  30.0
# 62                       гитара         0.624998  31.0
# 12                     грустный         0.620896  32.0
# 57                  вкусная еда         0.619671  33.0
# 60                  вкусная еда         0.616466  34.0
# 58                       музыка         0.615653  35.0
# 19                       музыка         0.611857  36.0
# 3                     печальный         0.610287  37.0
# 48                  вкусная еда         0.608100  38.0
# 34                         кафе         0.603830  39.0
# 20                       гитара         0.599162  40.0
# 41                         кафе         0.585826  41.0
# 44                       гитара         0.584974  42.0
# 0            зимние виды спорта         0.573048  43.0
# 23  хотел бы чтобы ты был здесь         0.571767  44.0
# 6               розовая пантера         0.564017  45.0
# 56                         кафе         0.563927  46.0
# 49                       музыка         0.561901  47.0
# 25              розовая пантера         0.561570  48.0
# 11                         лыжи         0.560637  49.0
# 46              розовая пантера         0.548848  50.0
# 4   хотел бы чтобы ты был здесь         0.532737  51.0
# 31  хотел бы чтобы ты был здесь         0.523507  52.0
# 17                         кафе         0.523179  53.0
# 47                         кафе         0.510100  54.0
# 50                       гитара         0.468172  55.0
# 24                   Pink floyd         0.205698  56.0
# 54                       музыка         0.188445  57.0
# 52                         кафе         0.178088  58.0
# 55                       гитара         0.144897  59.0
# 32                   Pink floyd         0.143941  60.0
# 39                   Pink floyd         0.118852  61.0
# 5                    Pink floyd         0.106783  62.0
# 53                  вкусная еда         0.104930  63.0
# 15                   Pink floyd         0.060774  64.0
# 51              розовая пантера         0.039542  65.0
# 45                   Pink floyd         0.037389  66.0
# sorted by Sim(RU by RU)
#              Word 1 EN           Word 2 EN                    Word 1 RU  \
# 30                 Sad           sorrowful                     грустный
# 65               music              guitar                       музыка
# 11       winter sports                 Ski           зимние виды спорта
# 29                 Ski              guitar                         лыжи
# 1                 snow                 Ski                         снег
# 28                 Ski               music                         лыжи
# 19       winter sports               music           зимние виды спорта
# 61                cafe               music                         кафе
# 0                 snow       winter sports                         снег
# 9                 snow               music                         снег
# 62                cafe              guitar                         кафе
# 59         pink panter              guitar              розовая пантера
# 20       winter sports              guitar           зимние виды спорта
# 55          Pink floyd              guitar                   Pink floyd
# 58         pink panter               music              розовая пантера
# 54          Pink floyd               music                   Pink floyd
# 60                cafe          tasty food                         кафе
# 26                 Ski                cafe                         лыжи
# 63          tasty food               music                  вкусная еда
# 36                 Sad               music                     грустный
# 10                snow              guitar                         снег
# 6                 snow         pink panter                         снег
# 43           sorrowful               music                    печальный
# 52          Pink floyd                cafe                   Pink floyd
# 7                 snow                cafe                         снег
# 8                 snow          tasty food                         снег
# 27                 Ski          tasty food                         лыжи
# 64          tasty food              guitar                  вкусная еда
# 51          Pink floyd         pink panter                   Pink floyd
# 16       winter sports         pink panter           зимние виды спорта
# 3                 snow           sorrowful                         снег
# 37                 Sad              guitar                     грустный
# 33                 Sad         pink panter                     грустный
# 25                 Ski         pink panter                         лыжи
# 44           sorrowful              guitar                    печальный
# 40           sorrowful         pink panter                    печальный
# 24                 Ski          Pink floyd                         лыжи
# 2                 snow                 Sad                         снег
# 17       winter sports                cafe           зимние виды спорта
# 12       winter sports                 Sad           зимние виды спорта
# 57         pink panter          tasty food              розовая пантера
# 56         pink panter                cafe              розовая пантера
# 18       winter sports          tasty food           зимние виды спорта
# 5                 snow          Pink floyd                         снег
# 21                 Ski                 Sad                         лыжи
# 32                 Sad          Pink floyd                     грустный
# 22                 Ski           sorrowful                         лыжи
# 13       winter sports           sorrowful           зимние виды спорта
# 15       winter sports          Pink floyd           зимние виды спорта
# 53          Pink floyd          tasty food                   Pink floyd
# 34                 Sad                cafe                     грустный
# 39           sorrowful          Pink floyd                    печальный
# 41           sorrowful                cafe                    печальный
# 49  wish yor were here               music  хотел бы чтобы ты был здесь
# 42           sorrowful          tasty food                    печальный
# 38           sorrowful  wish yor were here                    печальный
# 35                 Sad          tasty food                     грустный
# 31                 Sad  wish yor were here                     грустный
# 47  wish yor were here                cafe  хотел бы чтобы ты был здесь
# 46  wish yor were here         pink panter  хотел бы чтобы ты был здесь
# 4                 snow  wish yor were here                         снег
# 50  wish yor were here              guitar  хотел бы чтобы ты был здесь
# 45  wish yor were here          Pink floyd  хотел бы чтобы ты был здесь
# 14       winter sports  wish yor were here           зимние виды спорта
# 48  wish yor were here          tasty food  хотел бы чтобы ты был здесь
# 23                 Ski  wish yor were here                         лыжи
#
#                       Word 2 RU  Sim(RU by RU)  Rank
# 30                    печальный       0.941616   1.0
# 65                       гитара       0.870257   2.0
# 11                         лыжи       0.795187   3.0
# 29                       гитара       0.628148   4.0
# 1                          лыжи       0.599416   5.0
# 28                       музыка       0.587576   6.0
# 19                       музыка       0.566123   7.0
# 61                       музыка       0.544291   8.0
# 0            зимние виды спорта       0.523946   9.0
# 9                        музыка       0.523527  10.0
# 62                       гитара       0.521371  11.0
# 59                       гитара       0.518202  12.0
# 20                       гитара       0.517557  13.0
# 55                       гитара       0.510830  14.0
# 58                       музыка       0.500760  15.0
# 54                       музыка       0.495802  16.0
# 60                  вкусная еда       0.495542  17.0
# 26                         кафе       0.486957  18.0
# 63                       музыка       0.467179  19.0
# 36                       музыка       0.464637  20.0
# 10                       гитара       0.454950  21.0
# 6               розовая пантера       0.454556  22.0
# 43                       музыка       0.442158  23.0
# 52                         кафе       0.419565  24.0
# 7                          кафе       0.414620  25.0
# 8                   вкусная еда       0.409123  26.0
# 27                  вкусная еда       0.407788  27.0
# 64                       гитара       0.405229  28.0
# 51              розовая пантера       0.399038  29.0
# 16              розовая пантера       0.386365  30.0
# 3                     печальный       0.381386  31.0
# 37                       гитара       0.380198  32.0
# 33              розовая пантера       0.378993  33.0
# 25              розовая пантера       0.378723  34.0
# 44                       гитара       0.370490  35.0
# 40              розовая пантера       0.363502  36.0
# 24                   Pink floyd       0.359343  37.0
# 2                      грустный       0.353325  38.0
# 17                         кафе       0.353047  39.0
# 12                     грустный       0.352010  40.0
# 57                  вкусная еда       0.349515  41.0
# 56                         кафе       0.338756  42.0
# 18                  вкусная еда       0.334025  43.0
# 5                    Pink floyd       0.333497  44.0
# 21                     грустный       0.331726  45.0
# 32                   Pink floyd       0.329383  46.0
# 22                    печальный       0.328703  47.0
# 13                    печальный       0.324645  48.0
# 15                   Pink floyd       0.317399  49.0
# 53                  вкусная еда       0.304733  50.0
# 34                         кафе       0.292245  51.0
# 39                   Pink floyd       0.290620  52.0
# 41                         кафе       0.287278  53.0
# 49                       музыка       0.270965  54.0
# 42                  вкусная еда       0.263330  55.0
# 38  хотел бы чтобы ты был здесь       0.259198  56.0
# 35                  вкусная еда       0.258867  57.0
# 31  хотел бы чтобы ты был здесь       0.250777  58.0
# 47                         кафе       0.247637  59.0
# 46              розовая пантера       0.223561  60.0
# 4   хотел бы чтобы ты был здесь       0.221821  61.0
# 50                       гитара       0.204536  62.0
# 45                   Pink floyd       0.183163  63.0
# 14  хотел бы чтобы ты был здесь       0.156634  64.0
# 48                  вкусная еда       0.150167  65.0
# 23  хотел бы чтобы ты был здесь       0.150068  66.0
# sorted by Sim(RU by Mult)
#              Word 1 EN           Word 2 EN                    Word 1 RU  \
# 30                 Sad           sorrowful                     грустный
# 51          Pink floyd         pink panter                   Pink floyd
# 1                 snow                 Ski                         снег
# 65               music              guitar                       музыка
# 0                 snow       winter sports                         снег
# 11       winter sports                 Ski           зимние виды спорта
# 60                cafe          tasty food                         кафе
# 29                 Ski              guitar                         лыжи
# 2                 snow                 Sad                         снег
# 26                 Ski                cafe                         лыжи
# 7                 snow                cafe                         снег
# 9                 snow               music                         снег
# 61                cafe               music                         кафе
# 28                 Ski               music                         лыжи
# 36                 Sad               music                     грустный
# 3                 snow           sorrowful                         снег
# 37                 Sad              guitar                     грустный
# 10                snow              guitar                         снег
# 63          tasty food               music                  вкусная еда
# 32                 Sad          Pink floyd                     грустный
# 34                 Sad                cafe                     грустный
# 62                cafe              guitar                         кафе
# 21                 Ski                 Sad                         лыжи
# 43           sorrowful               music                    печальный
# 19       winter sports               music           зимние виды спорта
# 39           sorrowful          Pink floyd                    печальный
# 22                 Ski           sorrowful                         лыжи
# 35                 Sad          tasty food                     грустный
# 41           sorrowful                cafe                    печальный
# 44           sorrowful              guitar                    печальный
# 24                 Ski          Pink floyd                         лыжи
# 33                 Sad         pink panter                     грустный
# 42           sorrowful          tasty food                    печальный
# 40           sorrowful         pink panter                    печальный
# 5                 snow          Pink floyd                         снег
# 8                 snow          tasty food                         снег
# 55          Pink floyd              guitar                   Pink floyd
# 18       winter sports          tasty food           зимние виды спорта
# 54          Pink floyd               music                   Pink floyd
# 53          Pink floyd          tasty food                   Pink floyd
# 59         pink panter              guitar              розовая пантера
# 57         pink panter          tasty food              розовая пантера
# 64          tasty food              guitar                  вкусная еда
# 27                 Ski          tasty food                         лыжи
# 56         pink panter                cafe              розовая пантера
# 25                 Ski         pink panter                         лыжи
# 6                 snow         pink panter                         снег
# 58         pink panter               music              розовая пантера
# 20       winter sports              guitar           зимние виды спорта
# 52          Pink floyd                cafe                   Pink floyd
# 17       winter sports                cafe           зимние виды спорта
# 48  wish yor were here          tasty food  хотел бы чтобы ты был здесь
# 16       winter sports         pink panter           зимние виды спорта
# 4                 snow  wish yor were here                         снег
# 47  wish yor were here                cafe  хотел бы чтобы ты был здесь
# 15       winter sports          Pink floyd           зимние виды спорта
# 12       winter sports                 Sad           зимние виды спорта
# 49  wish yor were here               music  хотел бы чтобы ты был здесь
# 14       winter sports  wish yor were here           зимние виды спорта
# 45  wish yor were here          Pink floyd  хотел бы чтобы ты был здесь
# 46  wish yor were here         pink panter  хотел бы чтобы ты был здесь
# 50  wish yor were here              guitar  хотел бы чтобы ты был здесь
# 13       winter sports           sorrowful           зимние виды спорта
# 23                 Ski  wish yor were here                         лыжи
# 31                 Sad  wish yor were here                     грустный
# 38           sorrowful  wish yor were here                    печальный
#
#                       Word 2 RU  Sim(RU by Mult)  Rank
# 30                    печальный         0.886939   1.0
# 51              розовая пантера         0.864301   2.0
# 1                          лыжи         0.663878   3.0
# 65                       гитара         0.567460   4.0
# 0            зимние виды спорта         0.488915   5.0
# 11                         лыжи         0.484480   6.0
# 60                  вкусная еда         0.399614   7.0
# 29                       гитара         0.396394   8.0
# 2                      грустный         0.390410   9.0
# 26                         кафе         0.351549  10.0
# 7                          кафе         0.348073  11.0
# 9                        музыка         0.347001  12.0
# 61                       музыка         0.344184  13.0
# 28                       музыка         0.338910  14.0
# 36                       музыка         0.334335  15.0
# 3                     печальный         0.330676  16.0
# 37                       гитара         0.327189  17.0
# 10                       гитара         0.319104  18.0
# 63                       музыка         0.314207  19.0
# 32                   Pink floyd         0.312603  20.0
# 34                         кафе         0.303174  21.0
# 62                       гитара         0.299829  22.0
# 21                     грустный         0.296703  23.0
# 43                       музыка         0.296403  24.0
# 19                       музыка         0.291050  25.0
# 39                   Pink floyd         0.285604  26.0
# 22                    печальный         0.283694  27.0
# 35                  вкусная еда         0.281325  28.0
# 41                         кафе         0.279043  29.0
# 44                       гитара         0.275669  30.0
# 24                   Pink floyd         0.263522  31.0
# 33              розовая пантера         0.261651  32.0
# 42                  вкусная еда         0.250918  33.0
# 40              розовая пантера         0.245557  34.0
# 5                    Pink floyd         0.236972  35.0
# 8                   вкусная еда         0.231453  36.0
# 55                       гитара         0.229383  37.0
# 18                  вкусная еда         0.222498  38.0
# 54                       музыка         0.220207  39.0
# 53                  вкусная еда         0.218500  40.0
# 59                       гитара         0.212674  41.0
# 57                  вкусная еда         0.211338  42.0
# 64                       гитара         0.207490  43.0
# 27                  вкусная еда         0.207384  44.0
# 56                         кафе         0.204191  45.0
# 25              розовая пантера         0.204041  46.0
# 6               розовая пантера         0.202674  47.0
# 58                       музыка         0.193531  48.0
# 20                       гитара         0.182388  49.0
# 52                         кафе         0.166548  50.0
# 17                         кафе         0.148998  51.0
# 48                  вкусная еда         0.084981  52.0
# 16              розовая пантера         0.071443  53.0
# 4   хотел бы чтобы ты был здесь         0.062780  54.0
# 47                         кафе         0.061528  55.0
# 15                   Pink floyd         0.054797  56.0
# 12                     грустный         0.050978  57.0
# 49                       музыка         0.047223  58.0
# 14  хотел бы чтобы ты был здесь         0.046017  59.0
# 45                   Pink floyd         0.045055  60.0
# 46              розовая пантера         0.042199  61.0
# 50                       гитара         0.040840  62.0
# 13                    печальный         0.035722  63.0
# 23  хотел бы чтобы ты был здесь         0.031591  64.0
# 31  хотел бы чтобы ты был здесь         0.017164  65.0
# 38  хотел бы чтобы ты был здесь        -0.036519  66.0

# %%
import openai
from numpy import dot
from numpy.linalg import norm
import numpy as np

client = OpenAI() # api_key=''

def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

def cosine_similarity(vec1, vec2):
    return dot(vec1, vec2) / (norm(vec1) * norm(vec2))

   # Words for which embeddings are required
word1 = "money"
word2 = "bank"

embedding1 = get_embedding( word1)
embedding2 = get_embedding( word2)

print(f"Embedding for '{word1}': {embedding1}")
print(f"Embedding for '{word2}': {embedding2}")
# Compute cosine similarity
similarity = cosine_similarity(np.array(embedding1), np.array(embedding2))

# Output the result
print(f"Cosine Similarity between '{word1}' and '{word2}': {similarity}")
# Out:
# Embedding for 'money': [0.022288266569375992, -0.015567759051918983, -0.003337214235216379, 0.07599561661481857, -0.0010394456330686808, -0.04349898546934128, -0.007092688232660294, 0.06159047782421112, -0.0499926395714283, -0.058868248015642166, 0.01616324670612812, 0.018857121467590332, -0.03433981165289879, -0.05535203218460083, 0.03553078696131706, 0.021253252401947975, -0.015326728112995625, 0.006178188603371382, -0.019495144486427307, 0.007213203236460686, 0.0023146052844822407, 0.010229634121060371, 0.000506873766425997, 0.004267664160579443, 0.0242590494453907, 0.010938548482954502, 0.01984960213303566, -0.054132699966430664, 0.037742599844932556, -0.060002509504556656, 0.02510974556207657, -0.038876861333847046, 0.029207270592451096, -0.027463341131806374, -0.022997181862592697, 0.004590220283716917, -0.034935299307107925, -0.012682477943599224, 0.027633480727672577, -0.0587548203766346, -0.04605107754468918, -0.016375921666622162, 0.01262576412409544, 0.0008161376463249326, 0.009428560733795166, 0.016177425161004066, -0.023507598787546158, -0.03476515784859657, 0.03408460319042206, 0.05353721231222153, -0.02648504078388214, -0.017198262736201286, 0.004228673875331879, 0.03921714052557945, 0.023436708375811577, 0.013313411734998226, -0.0242590494453907, 0.00591943459585309, 0.015851324424147606, -0.04364076629281044, -0.042676642537117004, -0.017467649653553963, 0.0035977403167635202, -0.01685798354446888, 0.005196342244744301, -0.014157019555568695, -0.0470719113945961, 0.027009636163711548, -0.01501480583101511, 0.06936018168926239, 0.026513395830988884, 0.05903838574886322, 0.02021823637187481, 0.03065345622599125, -0.0016960775246843696, 0.0028462910559028387, -0.026867853477597237, -0.043952688574790955, 0.052885010838508606, 0.010952726937830448, -0.027349915355443954, 0.002601715736091137, -0.05481325834989548, 0.005054559092968702, 0.04074839502573013, -0.02467021904885769, -0.03258170187473297, 0.02546420320868492, 0.00681266700848937, -0.0027771720197051764, -0.04576750844717026, -0.022798685356974602, -0.025705233216285706, 0.03068181313574314, 0.026244008913636208, -0.0053274910897016525, -0.024585150182247162, -0.015936395153403282, -0.02495378442108631, 0.01980706676840782, 0.024769466370344162, -0.010038226842880249, -0.008436080999672413, -0.023039715364575386, 0.026555931195616722, 0.06737522035837173, 0.016829626634716988, -0.02861178293824196, 0.011271738447248936, 0.018289990723133087, -0.04658985137939453, -0.0020239504519850016, -0.05067319795489311, 0.021536817774176598, -0.019140686839818954, -0.003608373925089836, -0.02601715549826622, -0.009804285131394863, 0.0259037297219038, 0.0016792408423498273, -0.005097093991935253, 0.026882031932473183, 0.01646099053323269, -0.03156086802482605, 0.008003642782568932, 0.036324769258499146, -0.058698106557130814, 0.040152907371520996, -0.027392450720071793, 0.003938019275665283, 0.005416105501353741, 0.027605123817920685, -0.0046504782512784, 0.0032486000563949347, -0.015383441001176834, 0.019537679851055145, -0.011888493783771992, 0.025847017765045166, -0.0587548203766346, -0.00437754625454545, 0.03788438066840172, -0.012710833922028542, 0.027605123817920685, -0.007429422345012426, -0.012880973517894745, 0.018616091459989548, -0.0012370555195957422, 0.012824260629713535, -0.05004935339093208, -0.020586872473359108, -0.006589358672499657, -0.018545199185609818, 0.005550799425691366, -0.003034153487533331, -0.042166225612163544, -0.02784615568816662, 0.009208797477185726, 0.005309768486768007, -0.0543595515191555, 0.041230458766222, -0.011973563581705093, 0.005635869223624468, 0.0050191134214401245, -0.05115525797009468, 0.006086029578000307, 0.04976578801870346, -0.05370735004544258, -0.029689332470297813, -0.04386761784553528, -0.005841454025357962, -0.02620147354900837, 0.030228108167648315, 0.01648934744298458, 0.022458406165242195, 0.002966806525364518, -0.026811139658093452, 0.040039483457803726, 0.0022472585551440716, -0.005302679259330034, 0.01013 ...
# Embedding for 'bank': [0.0025784370955079794, -0.03409285098314285, 0.07600855827331543, 0.03396070748567581, 0.022266067564487457, -0.01929285377264023, 0.01949106901884079, 0.05629284679889679, -0.027644282206892967, -0.026573924347758293, -0.005890266969799995, -0.003809017362073064, -0.029969995841383934, -0.026124639436602592, -0.0012685712426900864, 0.049077849835157394, 0.0017740175826475024, 0.06342855840921402, -0.007637856062501669, -0.022900354117155075, 0.01737678237259388, -0.008952677249908447, 0.011846605688333511, 0.027829281985759735, -0.004846338648349047, -0.003987410105764866, -0.007221606094390154, -0.0661771297454834, 0.026441780850291252, -0.03107999451458454, 0.052407849580049515, -0.0315028540790081, 0.028701424598693848, 0.014866068959236145, 0.029679281637072563, 0.016200711950659752, -0.024776780977845192, 0.012963212095201015, 0.01059124805033207, -0.03369642421603203, -0.015738211572170258, 0.0016740845749154687, -0.014390354976058006, -0.024723924696445465, 0.01929285377264023, 0.02806713804602623, -0.006405624095350504, -0.05309499055147171, 0.020151782780885696, 0.04775642231106758, -0.03808356449007988, -0.017812853679060936, -0.00958696287125349, 0.03065713867545128, 0.01168142631649971, 0.018909640610218048, 0.021274996921420097, 0.01674249768257141, 0.034515708684921265, 0.0037330351769924164, -0.01089517679065466, 0.012361962348222733, -0.030551424250006676, -0.003785892156884074, 0.008212677203118801, -0.07177998870611191, -0.03591642156243324, 0.04461142048239708, -0.04963285103440285, 0.04593285173177719, -0.017165355384349823, 0.031317852437496185, -0.023957496508955956, 0.03792499378323555, -0.0031895977444946766, -0.030604280531406403, 0.0004073715826962143, -0.05396713316440582, 0.03232213854789734, 0.016782140359282494, -0.016147853806614876, -0.014641426503658295, -0.049659278243780136, 0.019530711695551872, 0.027485709637403488, -0.04381856322288513, -0.04503427818417549, 0.03932570666074753, 0.005791159812361002, -0.019477853551506996, -0.010426069609820843, -0.02246428281068802, -0.037845708429813385, 0.04561570659279823, 0.023481782525777817, 0.022120710462331772, -0.02732713893055916, -0.046487849205732346, 0.004684463609009981, -0.019900711253285408, 0.008919641375541687, -0.010796070098876953, 0.026904281228780746, -0.05808999016880989, 0.0022249550092965364, 0.037713564932346344, 0.018711425364017487, -0.012831069529056549, -0.02311178296804428, 0.039669279009103775, -0.06469713151454926, -0.032824281603097916, -0.04342213645577431, 0.03200499340891838, 0.019755354151129723, -0.019385354593396187, 0.023124996572732925, -0.032242853194475174, 0.024565353989601135, -0.04537785053253174, 0.04918356239795685, 0.005454195663332939, -0.0006429575150832534, 0.024116067215800285, 0.03945785015821457, 0.032692138105630875, -0.04609142243862152, 0.034515708684921265, -0.02246428281068802, -0.029520709067583084, -0.0357842817902565, 0.009289641864597797, -0.007195177488029003, 0.022001782432198524, -0.030419280752539635, -0.015672139823436737, 0.0009225221583619714, 0.012857497669756413, -0.03895570710301399, -0.03245428204536438, 0.029467852786183357, 0.0005880356184206903, 0.06876713037490845, -0.060151420533657074, -0.05084856227040291, -0.0003759876708500087, -0.006488213315606117, 0.013729640282690525, -0.022107496857643127, -0.013901426456868649, -0.007981427013874054, -0.005943124182522297, -0.025754638016223907, -0.023851782083511353, -0.04416213557124138, -0.012005176395177841, -0.022675711661577225, 0.028886424377560616, -0.019438210874795914, 0.05449570715427399, -0.028172852471470833, 0.019596783444285393, 0.00735374866053462, -0.03472713753581047, -0.037079278379678726, 0.0074924989603459835, -0.06892570108175278, -0.005358391907066107, -0.04503427818417549, 0.0041988384909927845, -0.00035740507883019745, 0.05082213506102562, -0.01715213991701603, 0.008278748951852322, -0.07262570410966873, 0.016412140801548958, 0.02554321102797985, -0.023772496730089188, -0.017693925648 ...
# Cosine Similarity between 'money' and 'bank': 0.5082802864694209
